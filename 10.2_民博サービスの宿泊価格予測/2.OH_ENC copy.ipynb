# %%
# Chapter1
# NN構築試行
import numpy as np
import pandas as pd
import tensorflow as tf
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, accuracy_score  # モデルの評価を行うための関数
from keras import metrics
# 学習データ読み込み
data_X = pd.read_csv("train.csv")
data = data_X.dropna(how="any")
data.head()
# Out:
#    id  accommodates                                          amenities  \
# 1   1             2  {TV,"Cable TV",Internet,"Wireless Internet","A...
# 4   4             2  {TV,Internet,"Wireless Internet","Air conditio...
# 5   5             2  {"Wireless Internet","Air conditioning",Kitche...
# 6   6             2  {Internet,"Wireless Internet",Kitchen,"Free pa...
# 8   8             2  {"Wireless Internet","Air conditioning","Pets ...
#
#    bathrooms  bed_type  bedrooms  beds cancellation_policy city cleaning_fee  \
# 1        1.0  Real Bed       1.0   1.0              strict   DC            t
# 4        1.0  Real Bed       1.0   1.0              strict  NYC            t
# 5        1.0  Real Bed       1.0   1.0            flexible  NYC            t
# 6        1.5  Real Bed       1.0   1.0            moderate  NYC            t
# 8        1.0  Real Bed       1.0   1.0              strict   SF            t
#
#                                          description first_review  \
# 1  This is a new listing for a lovely guest bedro...   2016-09-12
# 4  Charming Apartment on the upper west side of M...   2015-08-05
# 5  I have other listings in the same apartment: h...   2017-02-10
# 6  Stay in a Cozy, Private bedroom in newly renov...   2015-05-15
# 8  Very bright & cozy private room right in the h...   2017-06-06
#
#   host_has_profile_pic host_identity_verified host_response_rate  host_since  \
# 1                    t                      t               100%  2015-12-30
# 4                    t                      t               100%  2015-03-25
# 5                    t                      t               100%  2016-11-29
# 6                    t                      t               100%  2014-05-29
# 8                    t                      f               100%  2016-07-09
#
#   instant_bookable last_review   latitude   longitude  \
# 1                f  2017-03-31  38.934810  -76.978190
# 4                f  2017-09-10  40.785050  -73.974691
# 5                f  2017-09-15  40.640241  -74.015729
# 6                t  2017-09-05  40.676824  -73.915965
# 8                f  2017-09-16  37.801514 -122.411410
#
#                                                 name       neighbourhood  \
# 1                         Guest Bedroom in Brookland           Brookland
# 4                 Charming 1-bedroom - UWS Manhattan     Upper West Side
# 5         Close NYU Langone H, Room A/3min to Subway         Sunset Park
# 6  Cozy Artist Bedroom less than 30 min to Manhattan  Bedford-Stuyvesant
# 8                    PERFECT Location in North Beach         North Beach
#
#    number_of_reviews property_type  review_scores_rating        room_type  \
# 1                  9         House                 100.0     Private room
# 4                  5     Apartment                 100.0  Entire home/apt
# 5                  7         House                  94.0     Private room
# 6                 65         House                  91.0     Private room
# 8                 21     Apartment                  87.0     Private room
#
#                                        thumbnail_url zipcode      y
# 1  https://a0.muscache.com/im/pictures/e4d8b51f-6...   20018   42.0
# 4  https://a0.muscache.com/im/pictures/92879730/5...   10024  165.0
# 5  https://a0.muscache.com/im/pictures/dd071463-3...   11220   55.0
# 6  https://a0.muscache.com/im/pictures/79595629/9...   11233   48.0
# 8  https://a0.muscache.com/im/pictures/b1e47fdc-1...   94133   95.0

# %%
# # Chapter2
# 学習の再現を行うために乱数シードを固定するためのコード
import os
import random as rn
from tensorflow.compat.v1.keras import backend as K

os.environ['PYTHONHASHSEED'] = '0'
np.random.seed(0)
rn.seed(0)

tf.compat.v1.set_random_seed(0)
sess = tf.compat.v1.Session(graph=tf.compat.v1.get_default_graph())
K.set_session(sess)

pd.set_option("max_columns", None)
# pd.set_option('max_rows', None)

# %%
# Chapter3
# データ前処理
def pre_process(input_data_X: pd.DataFrame):
    # temp_data = input_data_X.drop(["id","amenities", "bed_type", "cancellation_policy", "city", "description", "first_review", "host_response_rate", "host_since"
    #                             , "last_review", "name", "neighbourhood", "property_type", "room_type", "thumbnail_url", "zipcode"], axis = 1).replace({"cleaning_fee": {"t":0, "f":1}, "host_has_profile_pic": {"t":0, "f":1}, "host_identity_verified": {"t":0, "f":1}, "instant_bookable": {"t":0, "f":1}})
    
    temp_data = input_data_X.drop(["id","amenities",  "description", "first_review", "host_response_rate", "host_since", "last_review", "name", "neighbourhood", "thumbnail_url", "zipcode"], axis = 1).replace({"cleaning_fee": {"t":0, "f":1}, "host_has_profile_pic": {"t":0, "f":1}, "host_identity_verified": {"t":0, "f":1}, "instant_bookable": {"t":0, "f":1}})
    temp_data = pd.get_dummies(temp_data)
    temp_data = temp_data.drop(["property_type_Earth House","property_type_Lighthouse","property_type_Tipi","property_type_Train","property_type_Treehouse","property_type_Vacation home"], axis=1, errors="ignore")


    processed_X = ((temp_data - temp_data.min()) / (temp_data.max() - temp_data.min()))
    # (x - train_stats['mean']) / train_stats['std']
    return processed_X
# train_dataset = data.sample(frac=0.8,random_state=0)
# test_dataset = data.drop(train_dataset.index)
train_dataset = data
test_dataset = data

train_y = train_dataset["y"]
test_y = test_dataset["y"]
train_X = pre_process(train_dataset.drop(["y"], axis=1))
test_X = pre_process(test_dataset.drop(["y"], axis=1))

# %%
# train_stats = train_dataset.describe()
# train_stats.pop("y")
# train_stats = train_stats.transpose()

# def norm(x):
#   return (x - train_stats['mean']) / train_stats['std']
# normed_train_data = norm(train_X)
# normed_test_data = norm(test_X)

# %%
test_X.dtypes
# Out:
# accommodates                           float64
# bathrooms                              float64
# bedrooms                               float64
# beds                                   float64
# cleaning_fee                           float64
# host_has_profile_pic                   float64
# host_identity_verified                 float64
# instant_bookable                       float64
# latitude                               float64
# longitude                              float64
# number_of_reviews                      float64
# review_scores_rating                   float64
# bed_type_Airbed                        float64
# bed_type_Couch                         float64
# bed_type_Futon                         float64
# bed_type_Pull-out Sofa                 float64
# bed_type_Real Bed                      float64
# cancellation_policy_flexible           float64
# cancellation_policy_moderate           float64
# cancellation_policy_strict             float64
# cancellation_policy_super_strict_30    float64
# cancellation_policy_super_strict_60    float64
# city_Boston                            float64
# city_Chicago                           float64
# city_DC                                float64
# city_LA                                float64
# city_NYC                               float64
# city_SF                                float64
# property_type_Apartment                float64
# property_type_Bed & Breakfast          float64
# property_type_Boat                     float64
# property_type_Boutique hotel           float64
# property_type_Bungalow                 float64
# property_type_Cabin                    float64
# property_type_Camper/RV                float64
# property_type_Castle                   float64
# property_type_Cave                     float64
# property_type_Chalet                   float64
# property_type_Condominium              float64
# property_type_Dorm                     float64
# property_type_Guest suite              float64
# property_type_Guesthouse               float64
# property_type_Hostel                   float64
# property_type_House                    float64
# property_type_Hut                      float64
# property_type_In-law                   float64
# property_type_Loft                     float64
# property_type_Other                    float64
# property_type_Serviced apartment       float64
# property_type_Tent                     float64
# property_type_Timeshare                float64
# property_type_Townhouse                float64
# property_type_Villa                    float64
# property_type_Yurt                     float64
# room_type_Entire home/apt              float64
# room_type_Private room                 float64
# room_type_Shared room                  float64
# dtype: object

# %%
import pathlib

import matplotlib.pyplot as plt
import seaborn as sns
from tensorflow import keras
from tensorflow.keras.layers import Dense, LSTM, Dropout
from tensorflow.keras.metrics import binary_accuracy, Accuracy
from tensorflow.keras.layers import SimpleRNN
import optuna

# %%
# hoge = train_dataset.drop(["id","amenities", "bed_type", "cancellation_policy", "city", "description", "first_review", "host_response_rate", "host_since"
#                                 , "last_review", "name", "neighbourhood", "property_type", "room_type", "thumbnail_url", "zipcode"], axis = 1).replace({"cleaning_fee": {"t":0, "f":1}, "host_has_profile_pic": {"t":0, "f":1}, "host_identity_verified": {"t":0, "f":1}, "instant_bookable": {"t":0, "f":1}})
# sns.pairplot(hoge[["y", "accommodates","host_identity_verified","instant_bookable", "number_of_reviews", "review_scores_rating"]], diag_kind="kde")

# %%
keras.backend.clear_session()
# Keras以外を利用するのも一つの手段。
model = keras.models.Sequential()
model.add(Dense(units=256, activation=tf.nn.relu, input_shape=[len(train_X.keys())])) 
# model.add(Dropout(0.5))
model.add(Dense(units=256, activation=tf.nn.relu)) 
# model.add(Dropout(0.5))
model.add(Dense(units=1))
model.compile(optimizer = keras.optimizers.Adam(learning_rate=0.001),
        loss=keras.losses.mse,
        metrics=["mae", "mse"])

# %%
history = model.fit(x = train_X,
    y = train_y,
    batch_size = 8192, # バッチサイズ
    # epochs = 100, # エポック数
    epochs = 700, # エポック数
    validation_split = 0.1, # 検証データの割合
    # callbacks = [es_cb], # 早期終了の設定
    verbose = 1) # 進捗の確認を行うか（0:行わない, 1:行う）
# Out:
#  inf - val_loss: inf - val_mae: 74591985932137660416.0000 - val_mse: inf
# Epoch 609/700
# 4/4 [==============================] - 0s 6ms/step - loss: inf - mae: 72950784507775025152.0000 - mse: inf - val_loss: inf - val_mae: 68801284799153045504.0000 - val_mse: inf
# Epoch 610/700
# 4/4 [==============================] - 0s 6ms/step - loss: inf - mae: 67287481588077559808.0000 - mse: inf - val_loss: inf - val_mae: 63460090407882326016.0000 - val_mse: inf
# Epoch 611/700
# 4/4 [==============================] - 0s 6ms/step - loss: inf - mae: 62063829387862605824.0000 - mse: inf - val_loss: inf - val_mae: 58533565831911047168.0000 - val_mse: inf
# Epoch 612/700
# 4/4 [==============================] - 0s 6ms/step - loss: inf - mae: 57245703464250507264.0000 - mse: inf - val_loss: inf - val_mae: 53989512972731416576.0000 - val_mse: inf
# Epoch 613/700
# 4/4 [==============================] - 0s 6ms/step - loss: inf - mae: 52801618202268270592.0000 - mse: inf - val_loss: inf - val_mae: 49798201035928371200.0000 - val_mse: inf
# Epoch 614/700
# 4/4 [==============================] - 0s 6ms/step - loss: inf - mae: 48702533300803076096.0000 - mse: inf - val_loss: inf - val_mae: 45932287366342377472.0000 - val_mse: inf
# Epoch 615/700
# 4/4 [==============================] - 0s 6ms/step - loss: inf - mae: 44921664656602300416.0000 - mse: inf - val_loss: inf - val_mae: 42366487594581098496.0000 - val_mse: inf
# Epoch 616/700
# 4/4 [==============================] - 0s 6ms/step - loss: inf - mae: 41434321636552605696.0000 - mse: inf - val_loss: inf - val_mae: 39077487676089171968.0000 - val_mse: inf
# Epoch 617/700
# 4/4 [==============================] - 0s 6ms/step - loss: inf - mae: 38217695971447406592.0000 - mse: inf - val_loss: inf - val_mae: 36043831740962177024.0000 - val_mse: inf
# Epoch 618/700
# 4/4 [==============================] - 0s 6ms/step - loss: inf - mae: 35250786989196181504.0000 - mse: inf - val_loss: inf - val_mae: 33245678002365267968.0000 - val_mse: inf
# Epoch 619/700
# 4/4 [==============================] - 0s 6ms/step - loss: inf - mae: 32514203702731472896.0000 - mse: inf - val_loss: inf - val_mae: 30664756975091318784.0000 - val_mse: inf
# Epoch 620/700
# 4/4 [==============================] - 0s 6ms/step - loss: inf - mae: 29990070252008898560.0000 - mse: inf - val_loss: inf - val_mae: 28284204349793501184.0000 - val_mse: inf
# Epoch 621/700
# 4/4 [==============================] - 0s 6ms/step - loss: inf - mae: 27661885166518796288.0000 - mse: inf - val_loss: inf - val_mae: 26088444444752740352.0000 - val_mse: inf
# Epoch 622/700
# 4/4 [==============================] - 0s 6ms/step - loss: inf - mae: 25514440001425768448.0000 - mse: inf - val_loss: inf - val_mae: 24063152822482370560.0000 - val_mse: inf
# Epoch 623/700
# 4/4 [==============================] - 0s 6ms/step - loss: inf - mae: 23533707187382648832.0000 - mse: inf - val_loss: inf - val_mae: 22195082566890946560.0000 - val_mse: inf
# Epoch 624/700
# 4/4 [==============================] - 0s 6ms/step - loss: inf - mae: 21706741074484002816.0000 - mse: inf - val_loss: inf - val_mae: 20472044492072943616.0000 - val_mse: inf
# Epoch 625/700
# 4/4 [==============================] - 0s 6ms/step - loss: inf - mae: 20021609762545205248.0000 - mse: inf - val_loss: inf - val_mae: 18882762006773891072.0000 - val_mse: inf
# Epoch 626/700
# 4/4 [==============================] - 0s 7ms/step - loss: inf - mae: 18467296145055940608.0000 - mse: inf - val_loss: inf - val_mae: 17416854621715955712.0000 - val_mse: inf
# Epoch 627/700
# 4/4 [==============================] - 0s 6ms/step - loss: inf - mae: 17033645132622069760.0000 - mse: inf - val_loss: inf - val_mae: 16064751088179347456.0000 - val_mse: inf
# Epoch 628/700
# 4/4 [==============================] - 0s 6ms/step - loss: inf - mae: 15711293284221452288.0000 - mse: inf - val_loss: inf - val_mae: 14817616830234886144.0000 - val_mse: inf
# Epoch 629/700
# 4/4 [==============================] - 0s 6ms/step - loss: inf - mae: 14491596239436513280.0000 - mse: inf - val_loss: inf - val_mae: 13667297869650984960.0000 - val_mse: inf
# Epoch 630/700
# 4/4 [==============================] - 0s 6ms/step - loss: inf - mae: 13366586937012387840.0000 - mse: inf - val_loss: inf - val_mae: 12606279044451794944.0000 - val_mse: inf
# Epoch 631/700
# 4/4 [==============================] - 0s 6ms/step - loss: inf - mae: 12328910743670882304.0000 - mse: inf - val_loss: inf - val_mae: 11627629033335816192.0000 - val_mse: inf
# Epoch 632/700
# 4/4 [==============================] - 0s 6ms/step - loss: inf - mae: 11371796866808152064.0000 - mse: inf - val_loss: inf - val_mae: 10724956375210786816.0000 - val_mse: inf
# Epoch 633/700
# 4/4 [==============================] - 0s 6ms/step - loss: inf - mae: 10488982488192385024.0000 - mse: inf - val_loss: inf - val_mae: 9892358891658805248.0000 - val_mse: inf
# Epoch 634/700
# 4/4 [==============================] - 0s 6ms/step - loss: inf - mae: 9674705067382407168.0000 - mse: inf - val_loss: inf - val_mae: 9124397298657263616.0000 - val_mse: inf
# Epoch 635/700
# 4/4 [==============================] - 0s 6ms/step - loss: inf - mae: 8923640219320713216.0000 - mse: inf - val_loss: inf - val_mae: 8416051226113736704.0000 - val_mse: inf
# Epoch 636/700
# 4/4 [==============================] - 0s 6ms/step - loss: inf - mae: 8230880823612538880.0000 - mse: inf - val_loss: inf - val_mae: 7762698327145054208.0000 - val_mse: inf
# Epoch 637/700
# 4/4 [==============================] - 0s 6ms/step - loss: inf - mae: 7591901840153772032.0000 - mse: inf - val_loss: inf - val_mae: 7160067548833120256.0000 - val_mse: inf
# Epoch 638/700
# 4/4 [==============================] - 0s 6ms/step - loss: inf - mae: 7002528423293747200.0000 - mse: inf - val_loss: inf - val_mae: 6604216592236544000.0000 - val_mse: inf
# Epoch 639/700
# 4/4 [==============================] - 0s 6ms/step - loss: inf - mae: 6458910083311992832.0000 - mse: inf - val_loss: inf - val_mae: 6091518718251106304.0000 - val_mse: inf
# Epoch 640/700
# 4/4 [==============================] - 0s 6ms/step - loss: inf - mae: 5957492099115909120.0000 - mse: inf - val_loss: inf - val_mae: 5618623714946973696.0000 - val_mse: inf
# Epoch 641/700
# 4/4 [==============================] - 0s 6ms/step - loss: inf - mae: 5495000674833793024.0000 - mse: inf - val_loss: inf - val_mae: 5182438106359398400.0000 - val_mse: inf
# Epoch 642/700
# 4/4 [==============================] - 0s 6ms/step - loss: inf - mae: 5068413802756702208.0000 - mse: inf - val_loss: inf - val_mae: 4780116906151510016.0000 - val_mse: inf
# Epoch 643/700
# 4/4 [==============================] - 0s 6ms/step - loss: inf - mae: 4674943121396596736.0000 - mse: inf - val_loss: inf - val_mae: 4409027608608505856.0000 - val_mse: inf
# Epoch 644/700
# 4/4 [==============================] - 0s 6ms/step - loss: inf - mae: 4312019072079364096.0000 - mse: inf - val_loss: inf - val_mae: 4066746890102767616.0000 - val_mse: inf
# Epoch 645/700
# 4/4 [==============================] - 0s 6ms/step - loss: inf - mae: 3977269183590170624.0000 - mse: inf - val_loss: inf - val_mae: 3751037519349678080.0000 - val_mse: inf
# Epoch 646/700
# 4/4 [==============================] - 0s 6ms/step - loss: inf - mae: 3668505977545555968.0000 - mse: inf - val_loss: inf - val_mae: 3459837362291343360.0000 - val_mse: inf
# Epoch 647/700
# 4/4 [==============================] - 0s 6ms/step - loss: inf - mae: 3383713224498085888.0000 - mse: inf - val_loss: inf - val_mae: 3191244538689617920.0000 - val_mse: inf
# Epoch 648/700
# 4/4 [==============================] - 0s 7ms/step - loss: inf - mae: 3121030001017749504.0000 - mse: inf - val_loss: inf - val_mae: 2943502303841222656.0000 - val_mse: inf
# Epoch 649/700
# 4/4 [==============================] - 0s 6ms/step - loss: inf - mae: 2878738320186146816.0000 - mse: inf - val_loss: inf - val_mae: 2714992451507978240.0000 - val_mse: inf
# Epoch 650/700
# 4/4 [==============================] - 0s 6ms/step - loss: inf - mae: 2655256259648815104.0000 - mse: inf - val_loss: inf - val_mae: 2504222119777271808.0000 - val_mse: inf
# Epoch 651/700
# 4/4 [==============================] - 0s 6ms/step - loss: inf - mae: 2449123942841974784.0000 - mse: inf - val_loss: inf - val_mae: 2309814445213220864.0000 - val_mse: inf
# Epoch 652/700
# 4/4 [==============================] - 0s 6ms/step - loss: inf - mae: 2258993643387879424.0000 - mse: inf - val_loss: inf - val_mae: 2130499904202604544.0000 - val_mse: inf
# Epoch 653/700
# 4/4 [==============================] - 0s 6ms/step - loss: inf - mae: 2083623875219816448.0000 - mse: inf - val_loss: inf - val_mae: 1965105042960678912.0000 - val_mse: inf
# Epoch 654/700
# 4/4 [==============================] - 0s 7ms/step - loss: inf - mae: 1921868672343736320.0000 - mse: inf - val_loss: inf - val_mae: 1812550415946874880.0000 - val_mse: inf
# Epoch 655/700
# 4/4 [==============================] - 0s 6ms/step - loss: inf - mae: 1772670167134765056.0000 - mse: inf - val_loss: inf - val_mae: 1671838491236892672.0000 - val_mse: inf
# Epoch 656/700
# 4/4 [==============================] - 0s 6ms/step - loss: inf - mae: 1635054467168600064.0000 - mse: inf - val_loss: inf - val_mae: 1542051039182585856.0000 - val_mse: inf
# Epoch 657/700
# 4/4 [==============================] - 0s 6ms/step - loss: inf - mae: 1508122171933720576.0000 - mse: inf - val_loss: inf - val_mae: 1422338549612544000.0000 - val_mse: inf
# Epoch 658/700
# 4/4 [==============================] - 0s 6ms/step - loss: inf - mae: 1391043837345923072.0000 - mse: inf - val_loss: inf - val_mae: 1311919682076278784.0000 - val_mse: inf
# Epoch 659/700
# 4/4 [==============================] - 0s 6ms/step - loss: inf - mae: 1283054478190182400.0000 - mse: inf - val_loss: inf - val_mae: 1210073019507015680.0000 - val_mse: inf
# Epoch 660/700
# 4/4 [==============================] - 0s 6ms/step - loss: inf - mae: 1183448757757280256.0000 - mse: inf - val_loss: inf - val_mae: 1116132945053089792.0000 - val_mse: inf
# Epoch 661/700
# 4/4 [==============================] - 0s 6ms/step - loss: inf - mae: 1091575421566189568.0000 - mse: inf - val_loss: inf - val_mae: 1029485450189864960.0000 - val_mse: inf
# Epoch 662/700
# 4/4 [==============================] - 0s 6ms/step - loss: inf - mae: 1006834411146051584.0000 - mse: inf - val_loss: inf - val_mae: 949564630026420224.0000 - val_mse: inf
# Epoch 663/700
# 4/4 [==============================] - 0s 6ms/step - loss: inf - mae: 928671984953327616.0000 - mse: inf - val_loss: inf - val_mae: 875847872942178304.0000 - val_mse: inf
# Epoch 664/700
# 4/4 [==============================] - 0s 6ms/step - loss: inf - mae: 856577488556392448.0000 - mse: inf - val_loss: inf - val_mae: 807854486197370880.0000 - val_mse: inf
# Epoch 665/700
# 4/4 [==============================] - 0s 6ms/step - loss: inf - mae: 790079781222744064.0000 - mse: inf - val_loss: inf - val_mae: 745139030143795200.0000 - val_mse: inf
# Epoch 666/700
# 4/4 [==============================] - 0s 6ms/step - loss: inf - mae: 728744349700980736.0000 - mse: inf - val_loss: inf - val_mae: 687292692614348800.0000 - val_mse: inf
# Epoch 667/700
# 4/4 [==============================] - 0s 7ms/step - loss: inf - mae: 672170628161208320.0000 - mse: inf - val_loss: inf - val_mae: 633936829292216320.0000 - val_mse: inf
# Epoch 668/700
# 4/4 [==============================] - 0s 6ms/step - loss: inf - mae: 619988837099110400.0000 - mse: inf - val_loss: inf - val_mae: 584723032430346240.0000 - val_mse: inf
# Epoch 669/700
# 4/4 [==============================] - 0s 6ms/step - loss: inf - mae: 571857921751646208.0000 - mse: inf - val_loss: inf - val_mae: 539330072834736128.0000 - val_mse: inf
# Epoch 670/700
# 4/4 [==============================] - 0s 6ms/step - loss: inf - mae: 527463524872486912.0000 - mse: inf - val_loss: inf - val_mae: 497460773128241152.0000 - val_mse: inf
# Epoch 671/700
# 4/4 [==============================] - 0s 6ms/step - loss: inf - mae: 486515547190591488.0000 - mse: inf - val_loss: inf - val_mae: 458842042110312448.0000 - val_mse: inf
# Epoch 672/700
# 4/4 [==============================] - 0s 6ms/step - loss: inf - mae: 448746429423288320.0000 - mse: inf - val_loss: inf - val_mae: 423221198264991744.0000 - val_mse: inf
# Epoch 673/700
# 4/4 [==============================] - 0s 7ms/step - loss: inf - mae: 413909434289356800.0000 - mse: inf - val_loss: inf - val_mae: 390365797962219520.0000 - val_mse: inf
# Epoch 674/700
# 4/4 [==============================] - 0s 7ms/step - loss: inf - mae: 381776859802632192.0000 - mse: inf - val_loss: inf - val_mae: 360060921038503936.0000 - val_mse: inf
# Epoch 675/700
# 4/4 [==============================] - 0s 7ms/step - loss: inf - mae: 352138802321424384.0000 - mse: inf - val_loss: 110296248504193812200577311336038400.0000 - val_mae: 332108861559275520.0000 - val_mse: 110296248504193812200577311336038400.0000
# Epoch 676/700
# 4/4 [==============================] - 0s 7ms/step - loss: inf - mae: 324801679079768064.0000 - mse: inf - val_loss: 93835973820075596233860006495125504.0000 - val_mae: 306326585198247936.0000 - val_mse: 93835973820075596233860006495125504.0000
# Epoch 677/700
# 4/4 [==============================] - 0s 7ms/step - loss: inf - mae: 299586681999196160.0000 - mse: inf - val_loss: 79832198025273088903357129413361664.0000 - val_mae: 282545901036109824.0000 - val_mse: 79832198025273088903357129413361664.0000
# Epoch 678/700
# 4/4 [==============================] - 0s 7ms/step - loss: inf - mae: 276329210753056768.0000 - mse: inf - val_loss: 67918268038950746279249057478082560.0000 - val_mae: 260611279717138432.0000 - val_mse: 67918268038950746279249057478082560.0000
# Epoch 679/700
# 4/4 [==============================] - 0s 7ms/step - loss: inf - mae: 254877292218548224.0000 - mse: inf - val_loss: 57782361620493052494852000086753280.0000 - val_mae: 240379612931031040.0000 - val_mse: 57782361620493052494852000086753280.0000
# Epoch 680/700
# 4/4 [==============================] - 0s 7ms/step - loss: inf - mae: 235090704303390720.0000 - mse: inf - val_loss: 49159089184278007726833082988232704.0000 - val_mae: 221718495425986560.0000 - val_mse: 49159089184278007726833082988232704.0000
# Epoch 681/700
# 4/4 [==============================] - 0s 6ms/step - loss: inf - mae: 216840151312105472.0000 - mse: inf - val_loss: 41822729695302472877388299468013568.0000 - val_mae: 204506087569752064.0000 - val_mse: 41822729695302472877388299468013568.0000
# Epoch 682/700
# 4/4 [==============================] - 0s 7ms/step - loss: inf - mae: 200006473672032256.0000 - mse: inf - val_loss: 35581248942912342616754197779972096.0000 - val_mae: 188629912758779904.0000 - val_mse: 35581248942912342616754197779972096.0000
# Epoch 683/700
# 4/4 [==============================] - 0s 7ms/step - loss: inf - mae: 184479617141178368.0000 - mse: inf - val_loss: 30271211607241082470278045745807360.0000 - val_mae: 173986221763067904.0000 - val_mse: 30271211607241082470278045745807360.0000
# Epoch 684/700
# 4/4 [==============================] - 0s 8ms/step - loss: inf - mae: 170158134592012288.0000 - mse: inf - val_loss: 25753629208317965652975819092393984.0000 - val_mae: 160479357070999552.0000 - val_mse: 25753629208317965652975819092393984.0000
# Epoch 685/700
# 4/4 [==============================] - 0s 6ms/step - loss: inf - mae: 156948447277088768.0000 - mse: inf - val_loss: 21910231430669745504144205289619456.0000 - val_mae: 148021048514707456.0000 - val_mse: 21910231430669745504144205289619456.0000
# Epoch 686/700
# 4/4 [==============================] - 0s 7ms/step - loss: inf - mae: 144764260713496576.0000 - mse: inf - val_loss: 18640418314943934881123801906544640.0000 - val_mae: 136529923643801600.0000 - val_mse: 18640418314943934881123801906544640.0000
# Epoch 687/700
# 4/4 [==============================] - 0s 7ms/step - loss: inf - mae: 133525946207567872.0000 - mse: inf - val_loss: 15858581355663792596384234906583040.0000 - val_mae: 125930872070209536.0000 - val_mse: 15858581355663792596384234906583040.0000
# Epoch 688/700
# 4/4 [==============================] - 0s 6ms/step - loss: inf - mae: 123160085588344832.0000 - mse: inf - val_loss: 13491892540318159728353188811636736.0000 - val_mae: 116154607381512192.0000 - val_mse: 13491892540318159728353188811636736.0000
# Epoch 689/700
# 4/4 [==============================] - 0s 9ms/step - loss: 12909111221843899112479752798076928.0000 - mae: 113598938631634944.0000 - mse: 12909111221843899112479752798076928.0000 - val_loss: 11478402873461117277314161647288320.0000 - val_mae: 107137314953625600.0000 - val_mse: 11478402873461117277314161647288320.0000
# Epoch 690/700
# 4/4 [==============================] - 0s 8ms/step - loss: 10982594270386890338034038505209856.0000 - mae: 104780039333085184.0000 - mse: 10982594270386890338034038505209856.0000 - val_loss: 9765402725129952679232361052766208.0000 - val_mae: 98820050655379456.0000 - val_mse: 9765402725129952679232361052766208.0000
# Epoch 691/700
# 4/4 [==============================] - 0s 6ms/step - loss: 9343586417173832561673096015118336.0000 - mae: 96645775001387008.0000 - mse: 9343586417173832561673096015118336.0000 - val_loss: 8308042765641395892128466656559104.0000 - val_mae: 91148465970610176.0000 - val_mse: 8308042765641395892128466656559104.0000
# Epoch 692/700
# 4/4 [==============================] - 0s 6ms/step - loss: 7949177565592996289618234434387968.0000 - mae: 89142982531350528.0000 - mse: 7949177565592996289618234434387968.0000 - val_loss: 7068174634744828637451187046580224.0000 - val_mae: 84072438630973440.0000 - val_mse: 7068174634744828637451187046580224.0000
# Epoch 693/700
# 4/4 [==============================] - 0s 6ms/step - loss: 6762866434616032441773915635712000.0000 - mae: 82222656346128384.0000 - mse: 6762866434616032441773915635712000.0000 - val_loss: 6013342020490266815153216983924736.0000 - val_mae: 77545737608495104.0000 - val_mse: 6013342020490266815153216983924736.0000
# Epoch 694/700
# 4/4 [==============================] - 0s 6ms/step - loss: 5753596203507369040493607840120832.0000 - mae: 75839553260224512.0000 - mse: 5753596203507369040493607840120832.0000 - val_loss: 5115930813391391090132519154089984.0000 - val_mae: 71525726762827776.0000 - val_mse: 5115930813391391090132519154089984.0000
# Epoch 695/700
# 4/4 [==============================] - 0s 6ms/step - loss: 4894947993888616785330688837550080.0000 - mae: 69951999205965824.0000 - mse: 4894947993888616785330688837550080.0000 - val_loss: 4352442745107496195356027105837056.0000 - val_mae: 65973042718703616.0000 - val_mse: 4352442745107496195356027105837056.0000
# Epoch 696/700
# 4/4 [==============================] - 0s 7ms/step - loss: 4164440505161343349147921807310848.0000 - mae: 64521498391478272.0000 - mse: 4164440505161343349147921807310848.0000 - val_loss: 3702897463404516093186868974190592.0000 - val_mae: 60851440247111680.0000 - val_mse: 3702897463404516093186868974190592.0000
# Epoch 697/700
# 4/4 [==============================] - 0s 7ms/step - loss: 3542951587023717284184008702296064.0000 - mae: 59512570091929600.0000 - mse: 3542951587023717284184008702296064.0000 - val_loss: 3150288148022748229408480590561280.0000 - val_mae: 56127427193077760.0000 - val_mse: 3150288148022748229408480590561280.0000
# Epoch 698/700
# 4/4 [==============================] - 0s 7ms/step - loss: 3014212540964459944211293956734976.0000 - mae: 54892503836393472.0000 - mse: 3014212540964459944211293956734976.0000 - val_loss: 2680149469603142935508665688391680.0000 - val_mae: 51770157101481984.0000 - val_mse: 2680149469603142935508665688391680.0000
# Epoch 699/700
# 4/4 [==============================] - 0s 6ms/step - loss: 2564380876206787117668389925945344.0000 - mae: 50631097414844416.0000 - mse: 2564380876206787117668389925945344.0000 - val_loss: 2280171971365066032723964825960448.0000 - val_mae: 47751141454249984.0000 - val_mse: 2280171971365066032723964825960448.0000
# Epoch 700/700
# 4/4 [==============================] - 0s 8ms/step - loss: 2181680223899481892672715603574784.0000 - mae: 46700510849269760.0000 - mse: 2181680223899481892672715603574784.0000 - val_loss: 1939886084911271238724487384924160.0000 - val_mae: 44044138001203200.0000 - val_mse: 1939886084911271238724487384924160.0000

# %%
hist = pd.DataFrame(history.history)
hist['epoch'] = history.epoch
hist.head()
# Out:
#            loss         mae           mse      val_loss     val_mae  \
# 0  31405.470703  127.430656  31405.470703  83939.570312  274.877838
# 1  52921.542969  187.416946  52921.542969  19763.755859   75.273041
# 2  38839.101562  147.620590  38839.101562  34804.253906  132.897400
# 3  33777.738281  129.720703  33777.738281  32172.888672  122.638702
# 4  31265.326172  119.696060  31265.326172  29925.287109  113.253387
#
#         val_mse  epoch
# 0  83939.570312      0
# 1  19763.755859      1
# 2  34804.253906      2
# 3  32172.888672      3
# 4  29925.287109      4

# %%
hist.tail()
# Out:
#              loss           mae           mse      val_loss       val_mae  \
# 695  4.164441e+33  6.452150e+16  4.164441e+33  3.702897e+33  6.085144e+16
# 696  3.542952e+33  5.951257e+16  3.542952e+33  3.150288e+33  5.612743e+16
# 697  3.014213e+33  5.489250e+16  3.014213e+33  2.680149e+33  5.177016e+16
# 698  2.564381e+33  5.063110e+16  2.564381e+33  2.280172e+33  4.775114e+16
# 699  2.181680e+33  4.670051e+16  2.181680e+33  1.939886e+33  4.404414e+16
#
#           val_mse  epoch
# 695  3.702897e+33    695
# 696  3.150288e+33    696
# 697  2.680149e+33    697
# 698  2.280172e+33    698
# 699  1.939886e+33    699

# %%
def plot_history(history):
  hist = pd.DataFrame(history.history)
  hist['epoch'] = history.epoch
  
  plt.figure()
  plt.xlabel('Epoch')
  plt.ylabel('Mean Abs Error [y]')
  plt.plot(hist['epoch'], hist['mae'],
           label='Train Error')
  plt.plot(hist['epoch'], hist['val_mae'],
           label = 'Val Error')
  plt.ylim([20,100])
  plt.legend()
  
  plt.figure()
  plt.xlabel('Epoch')
  plt.ylabel('Mean Square Error [$y^2$]')
  plt.plot(hist['epoch'], hist['mse'],
           label='Train Error')
  plt.plot(hist['epoch'], hist['val_mse'],
           label = 'Val Error')
  plt.ylim([5000,20000])
  plt.legend()
  plt.show()


plot_history(history)

# %%
# 重回帰
# 説明変数の重みを確認
from sklearn import linear_model  # 線形回帰を行うためのモジュール
# 変数の準備
# X = data_oh.drop(["loan_status_ChargedOff", "loan_status_FullyPaid"], axis=1)  # 説明変数の設定
# y = data_oh["loan_status_FullyPaid"]  # 目的変数の設定

# 学習
lr = linear_model.LinearRegression()  # 線形回帰モデルのインスタンスを作成
lr.fit(train_X, train_y)  # 回帰の実行

# 結果の確認
print("回帰係数:")
print(pd.DataFrame({"Name": train_X.columns,
                    "Coefficients": lr.coef_}).sort_values(by='Coefficients'))  # 回帰係数
print("切片:", lr.intercept_)  # 切片
print("決定係数:", lr.score(train_X, train_y))  # 決定係数
# Out:
# 回帰係数:
#                                    Name  Coefficients
# 27                              city_SF -1.244466e+14
# 25                              city_LA -1.244466e+14
# 23                         city_Chicago -1.244466e+14
# 24                              city_DC -1.244466e+14
# 26                             city_NYC -1.244466e+14
# 22                          city_Boston -1.244466e+14
# 18         cancellation_policy_moderate -2.878706e+13
# 17         cancellation_policy_flexible -2.878706e+13
# 19           cancellation_policy_strict -2.878706e+13
# 20  cancellation_policy_super_strict_30 -2.878706e+13
# 21  cancellation_policy_super_strict_60 -2.878706e+13
# 56                room_type_Shared room -1.488410e+13
# 55               room_type_Private room -1.488410e+13
# 54            room_type_Entire home/apt -1.488410e+13
# 9                             longitude -1.201657e+04
# 42                 property_type_Hostel -1.883631e+02
# 39                   property_type_Dorm -1.531282e+02
# 44                    property_type_Hut -1.305238e+02
# 45                 property_type_In-law -1.228234e+02
# 34              property_type_Camper/RV -1.140132e+02
# 49                   property_type_Tent -1.042416e+02
# 51              property_type_Townhouse -9.320517e+01
# 53                   property_type_Yurt -9.266499e+01
# 40            property_type_Guest suite -9.243250e+01
# 37                 property_type_Chalet -8.856435e+01
# 41             property_type_Guesthouse -8.848325e+01
# 32               property_type_Bungalow -8.536130e+01
# 3                                  beds -8.390904e+01
# 28              property_type_Apartment -8.258828e+01
# 43                  property_type_House -8.230953e+01
# 31         property_type_Boutique hotel -7.837278e+01
# 33                  property_type_Cabin -7.729249e+01
# 29        property_type_Bed & Breakfast -7.536453e+01
# 47                  property_type_Other -7.477183e+01
# 38            property_type_Condominium -6.729786e+01
# 10                    number_of_reviews -6.308493e+01
# 35                 property_type_Castle -6.199690e+01
# 36                   property_type_Cave -4.976600e+01
# 46                   property_type_Loft -3.791222e+01
# 6                host_identity_verified -2.772233e+00
# 30                   property_type_Boat -1.318699e+00
# 7                      instant_bookable  6.872372e+00
# 4                          cleaning_fee  7.829073e+00
# 48     property_type_Serviced apartment  1.008180e+01
# 5                  host_has_profile_pic  3.349530e+01
# 52                  property_type_Villa  3.820407e+01
# 50              property_type_Timeshare  4.687893e+01
# 11                 review_scores_rating  8.586933e+01
# 0                          accommodates  2.267914e+02
# 2                              bedrooms  3.415643e+02
# 1                             bathrooms  4.315316e+02
# 8                              latitude  5.481119e+02
# 16                    bed_type_Real Bed  8.956169e+11
# 15               bed_type_Pull-out Sofa  8.956169e+11
# 14                       bed_type_Futon  8.956169e+11
# 12                      bed_type_Airbed  8.956169e+11
# 13                       bed_type_Couch  8.956169e+11
# 切片: 167222179653815.4
# 決定係数: 0.5353783189491625

# %%
test_X.dtypes
# Out:
# accommodates                           float64
# bathrooms                              float64
# bedrooms                               float64
# beds                                   float64
# cleaning_fee                           float64
# host_has_profile_pic                   float64
# host_identity_verified                 float64
# instant_bookable                       float64
# latitude                               float64
# longitude                              float64
# number_of_reviews                      float64
# review_scores_rating                   float64
# bed_type_Airbed                        float64
# bed_type_Couch                         float64
# bed_type_Futon                         float64
# bed_type_Pull-out Sofa                 float64
# bed_type_Real Bed                      float64
# cancellation_policy_flexible           float64
# cancellation_policy_moderate           float64
# cancellation_policy_strict             float64
# cancellation_policy_super_strict_30    float64
# cancellation_policy_super_strict_60    float64
# city_Boston                            float64
# city_Chicago                           float64
# city_DC                                float64
# city_LA                                float64
# city_NYC                               float64
# city_SF                                float64
# property_type_Apartment                float64
# property_type_Bed & Breakfast          float64
# property_type_Boat                     float64
# property_type_Boutique hotel           float64
# property_type_Bungalow                 float64
# property_type_Cabin                    float64
# property_type_Camper/RV                float64
# property_type_Castle                   float64
# property_type_Cave                     float64
# property_type_Chalet                   float64
# property_type_Condominium              float64
# property_type_Dorm                     float64
# property_type_Guest suite              float64
# property_type_Guesthouse               float64
# property_type_Hostel                   float64
# property_type_House                    float64
# property_type_Hut                      float64
# property_type_In-law                   float64
# property_type_Loft                     float64
# property_type_Other                    float64
# property_type_Serviced apartment       float64
# property_type_Tent                     float64
# property_type_Timeshare                float64
# property_type_Townhouse                float64
# property_type_Villa                    float64
# property_type_Yurt                     float64
# room_type_Entire home/apt              float64
# room_type_Private room                 float64
# room_type_Shared room                  float64
# dtype: object

# %%
pd.set_option('max_rows', 100)
train_X.dtypes
# Out:
# accommodates                           float64
# bathrooms                              float64
# bedrooms                               float64
# beds                                   float64
# cleaning_fee                           float64
# host_has_profile_pic                   float64
# host_identity_verified                 float64
# instant_bookable                       float64
# latitude                               float64
# longitude                              float64
# number_of_reviews                      float64
# review_scores_rating                   float64
# bed_type_Airbed                        float64
# bed_type_Couch                         float64
# bed_type_Futon                         float64
# bed_type_Pull-out Sofa                 float64
# bed_type_Real Bed                      float64
# cancellation_policy_flexible           float64
# cancellation_policy_moderate           float64
# cancellation_policy_strict             float64
# cancellation_policy_super_strict_30    float64
# cancellation_policy_super_strict_60    float64
# city_Boston                            float64
# city_Chicago                           float64
# city_DC                                float64
# city_LA                                float64
# city_NYC                               float64
# city_SF                                float64
# property_type_Apartment                float64
# property_type_Bed & Breakfast          float64
# property_type_Boat                     float64
# property_type_Boutique hotel           float64
# property_type_Bungalow                 float64
# property_type_Cabin                    float64
# property_type_Camper/RV                float64
# property_type_Castle                   float64
# property_type_Cave                     float64
# property_type_Chalet                   float64
# property_type_Condominium              float64
# property_type_Dorm                     float64
# property_type_Guest suite              float64
# property_type_Guesthouse               float64
# property_type_Hostel                   float64
# property_type_House                    float64
# property_type_Hut                      float64
# property_type_In-law                   float64
# property_type_Loft                     float64
# property_type_Other                    float64
# property_type_Serviced apartment       float64
# property_type_Tent                     float64
# property_type_Timeshare                float64
# property_type_Townhouse                float64
# property_type_Villa                    float64
# property_type_Yurt                     float64
# room_type_Entire home/apt              float64
# room_type_Private room                 float64
# room_type_Shared room                  float64
# dtype: object

# %%
data_X = pd.read_csv("test.csv")
test_X = pre_process(data_X)
y_proba = model.predict(test_X)
y_proba
# Out:
# array([[4.404414e+16],
#        [4.404414e+16],
#        [4.404414e+16],
#        ...,
#        [4.404414e+16],
#        [4.404414e+16],
#        [4.404414e+16]], dtype=float32)

# %%
np.savetxt("C:\work\AI\workspace\\10.2_民博サービスの宿泊価格予測\\result.dat", y_proba.astype("float"), fmt="%0.10f",)

# %%
hoge = y_proba.astype("float")

# %%
np.savetxt("C:\work\AI\workspace\\10.2_民博サービスの宿泊価格予測\\hoge.dat", hoge)
